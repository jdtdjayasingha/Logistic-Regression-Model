# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
data = pd.read_csv('Resources/sample.csv')

# %%
data
# Out:
#     age  job
# 0    16    0
# 1    24    0
# 2    31    1
# 3    29    0
# 4    40    1
# 5    33    0
# 6    18    0
# 7    36    1
# 8    15    0
# 9    37    1
# 10   19    0
# 11   21    0
# 12   29    1
# 13   31    1
# 14   23    1
# 15   20    0
# 16   34    1
# 17   22    0
# 18   32    1
# 19   15    0
# 20   14    0
# 21   13    0
# 22   51    1
# 23   43    1
# 24   23    0
# 25   31    1

# %%
 data.head()
# Out:
#    age  job
# 0   16    0
# 1   24    0
# 2   31    1
# 3   29    0
# 4   40    1

# %%
data.tail()
# Out:
#     age  job
# 21   13    0
# 22   51    1
# 23   43    1
# 24   23    0
# 25   31    1

# %%
x = data.age.values
x
# Out:
# array([16, 24, 31, 29, 40, 33, 18, 36, 15, 37, 19, 21, 29, 31, 23, 20, 34,
#        22, 32, 15, 14, 13, 51, 43, 23, 31])

# %%
y = data.job.values
y
# Out:
# array([0, 0, 1, 0, 1, 0, 0, 1, 0, 1, 0, 0, 1, 1, 1, 0, 1, 0, 1, 0, 0, 0,
#        1, 1, 0, 1])

# %%
plt.scatter(x,y)

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2)

# %%
x_train
# Out:
# array([23, 14, 37, 21, 43, 33, 23, 18, 31, 16, 32, 36, 34, 20, 19, 51, 31,
#        13, 29, 15])

# %%
len(x_train)
# Out:
# 20

# %%
len(x_test)
# Out:
# 6
